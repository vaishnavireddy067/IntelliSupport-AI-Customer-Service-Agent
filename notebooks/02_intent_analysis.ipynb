# %% [markdown]
# # 02: Intent Taxonomy Analysis and Classifier Evaluation
#
# This notebook analyzes the 10 empirical intents discovered in AppleSupport customer tweets, evaluates class distribution, and examines classification performance.

# %%
import os
import sys
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.intents.taxonomy import INTENTS, INTENT_NAMES
print(f'Configured {len(INTENT_NAMES)} support intents: {INTENT_NAMES}')

# %% [markdown]
# ## 1. Class Distribution Across AppleSupport Training Data

# %%
results_path = os.path.join(project_root, 'reports', 'baseline_results.json')
if os.path.exists(results_path):
    with open(results_path, 'r') as f:
        results = json.load(f)
    print('Baseline evaluation results found.')
    for model_name, metrics in results['intent_classification'].items():
        print(f'{model_name}: Accuracy={metrics["accuracy"]}, Macro F1={metrics["macro_f1"]}, Weighted F1={metrics["weighted_f1"]}')
else:
    print('Run python scripts/run_evaluation.py to produce baseline_results.json')
